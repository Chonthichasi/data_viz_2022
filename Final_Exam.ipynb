# %% [markdown]
# <a href="https://colab.research.google.com/github/Chonthichasi/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **สมาชิก emulete**
#
# - นางสาว ณัฐธิดา  เมยดง 623020435-1 STAT
#
# - นางสาว ชลธิชา ศาลางาม 623020518-7 SI
#
# - นางสาว นัจนันท์ ศรีสิน  623021002-7 STAT

# %% [markdown]
# # โจทย์
#
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
#
# ( ดาวน์โหลดจากhttps://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR2TOFCt16PG2k9xeKIA7jnTEm63uTzd3nRacpzhJEp3d3-6QCtWz3tQskw ) )
#
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
# - user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# - RowKey เป็น String
# - date เป็น YYYY-MM-DD
# - phone เป็น String
# - site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# - time เป็น hh-mm-ss
# - urine มีค่า String
# - ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# - PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
# - จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# - ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# - อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))

# %% [markdown]
# # นำเข้าข้อมูล alldb.csv

# %%
import pandas as pd # ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os # จัดการไฟล์และpath ที่นำเข้า

# %%
from google.colab import drive # เชื่อมgoogle drive
drive.mount('/content/drive') 
path='/content/drive/My Drive/Final_Dataviz_2022'
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(os.path.join(path,'alldb.csv')) #อ่านไฟล์ csv เเล้วชี้ไปที่ไฟล์ alldb.csv
data # เรียกดูตาราง
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ## ตรวจสอบว่ามีค่า Missing หรือไม่

# %%
data.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data
#เนื่องจากมี True เกือบทุกคอลัมน์ แสดงว่ามีค่าที่เป็น Missing
# Out:
# Unnamed: 0      False
# user             True
# RowKey           True
# care             True
# date             True
# ov               True
# phone            True
# site             True
# time             True
# urine            True
# pid              True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %% [markdown]
# ## เลือกเฉพาะคอลัมน์ที่ต้องการ

# %%
data_all = data[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey','title','age']] # เลือกเฉพาะคอลัมน์ที่ต้องการ คือ user,RowKey,date,phone,site,time,urine,ov,PartitionKey,title เเละ age
data_all # เรียกดูตารางข้อมูล data_all
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)    0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)    2
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)    1
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)    1
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %% [markdown]
# ## user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data_alldb = data_all[(data_all['user'].astype(str).str.isdigit())& (data_all['user'].str.len() == 5)]  # สร้างตัวแปร data_alldb มารับคอลัมน์ user โดยใช้คำสั่ง str.isdigit() เพื่อตรวจสอบว่าเป็นตัวเลขหรือไม่ เเละเปลียนคอลัมน์ user เป็นตัวเลข 5 หลัก
data_alldb
# Out:
#         user                                RowKey        date  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD  2022-02-25
# 7      04857  73E96EE6-7660-4204-9914-92112603C514  2022-02-24
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  2022-02-25
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  2022-02-27
# ...      ...                                   ...         ...
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
# 40017  12345                        zgvicawbkg.png         NaN
#
#                   phone   site      time                 urine   ov  \
# 1            iPhone10,4  05310  10:50:32                   NaN  NaN
# 5            iPhone13,2  05248  10:14:46                   NaN  NaN
# 7            iPhone10,4  05310  11:14:21                   NaN  NaN
# 11           iPhone13,2  05248  10:14:32                   NaN  NaN
# 12           iPhone13,3  22222  17:39:35                   NaN  NaN
# ...                 ...    ...       ...                   ...  ...
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน    0
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง    1
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)    1
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)    1
# 40017  Samsung SM-G998B  xxxxx       NaN       ปกติ (เหลืองใส)    2
#
#       PartitionKey                  title                    age
# 1              NaN  data is not completed  data is not completed
# 5              NaN  data is not completed  data is not completed
# 7              NaN  data is not completed  data is not completed
# 11             NaN  data is not completed  data is not completed
# 12             NaN  data is not completed  data is not completed
# ...            ...                    ...                    ...
# 39813        99999                    NaN                    NaN
# 39814        99999                    NaN                    NaN
# 39815        99999                    NaN                    NaN
# 39816        99999                    NaN                    NaN
# 40017        xxxxx                    NaN                    NaN
#
# [38508 rows x 11 columns]

# %% [markdown]
# ## ตรวจสอบว่ามีค่า Missing หรือไม่

# %%
data_alldb.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_user
#พบว่าคอลัมน์ user เป็นค่า False เเสดงว่า ไม่มีค่า Missing
# Out:
# user            False
# RowKey          False
# date             True
# phone           False
# site             True
# time             True
# urine            True
# ov               True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %%
set(data_alldb['user']) # เรียกดู set ข้อมูลของ user
# Out:
# {'06316',
#  '51175',
#  '00033',
#  '87541',
#  '86050',
#  '61813',
#  '84540',
#  '37127',
#  '68112',
#  '70455',
#  '63312',
#  '03649',
#  '21010',
#  '76331',
#  '01431',
#  '42370',
#  '92648',
#  '40865',
#  '92747',
#  '14255',
#  '02075',
#  '00014',
#  '33643',
#  '35178',
#  '54679',
#  '38422',
#  '95291',
#  '54214',
#  '35512',
#  '00027',
#  '23889',
#  '00038',
#  '19875',
#  '84459',
#  '50144',
#  '55415',
#  '55659',
#  '60879',
#  '02471',
#  '05849',
#  '84409',
#  '38614',
#  '66205',
#  '23078',
#  '54427',
#  '06655',
#  '89681',
#  '23796',
#  '50047',
#  '55911',
#  '88708',
#  '90516',
#  '11282',
#  '02878',
#  '29051',
#  '23416',
#  '23231',
#  '54761',
#  '44888',
#  '00216',
#  '47858',
#  '22688',
#  '39448',
#  '97016',
#  '46783',
#  '43228',
#  '01882',
#  '52219',
#  '55075',
#  '49367',
#  '39539',
#  '00399',
#  '79590',
#  '00296',
#  '62415',
#  '47810',
#  '00076',
#  '46313',
#  '61552',
#  '26776',
#  '74523',
#  '63098',
#  '78673',
#  '13978',
#  '19632',
#  '24501',
#  '00301',
#  '49178',
#  '30431',
#  '46897',
#  '61746',
#  '28977',
#  '93028',
#  '19250',
#  '75347',
#  '77254',
#  '84187',
#  '86271',
#  '05154',
#  '46520',
#  '30041',
#  '00400',
#  '90604',
#  '66062',
#  '83303',
#  '12561',
#  '32082',
#  '34801',
#  '71891',
#  '28917',
#  '20454',
#  '37728',
#  '91125',
#  '05116',
#  '07166',
#  '56004',
#  '58870',
#  '33103',
#  '12786',
#  '71921',
#  '79001',
#  '94019',
#  '46627',
#  '02962',
#  '00270',
#  '29025',
#  '00138',
#  '24229',
#  '77706',
#  '33739',
#  '96699',
#  '68037',
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         user                                RowKey        date  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD  2022-02-25
# 7      04857  73E96EE6-7660-4204-9914-92112603C514  2022-02-24
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  2022-02-25
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  2022-02-27
# ...      ...                                   ...         ...
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
# 40017  12345                        zgvicawbkg.png         NaN
#
#                   phone   site      time                 urine   ov  \
# 1            iPhone10,4  05310  10:50:32                   NaN  NaN
# 5            iPhone13,2  05248  10:14:46                   NaN  NaN
# 7            iPhone10,4  05310  11:14:21                   NaN  NaN
# 11           iPhone13,2  05248  10:14:32                   NaN  NaN
# 12           iPhone13,3  22222  17:39:35                   NaN  NaN
# ...                 ...    ...       ...                   ...  ...
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน    0
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง    1
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)    1
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)    1
# 40017  Samsung SM-G998B  xxxxx       NaN       ปกติ (เหลืองใส)    2
#
#       PartitionKey                  title                    age
# 1              NaN  data is not completed  data is not completed
# 5              NaN  data is not completed  data is not completed
# 7              NaN  data is not completed  data is not completed
# 11             NaN  data is not completed  data is not completed
# 12             NaN  data is not completed  data is not completed
# ...            ...                    ...                    ...
# 39813        99999                    NaN                    NaN
# 39814        99999                    NaN                    NaN
# 39815        99999                    NaN                    NaN
# 39816        99999                    NaN                    NaN
# 40017        xxxxx                    NaN                    NaN
#
# [38508 rows x 11 columns]

# %% [markdown]
# ## date เป็น YYYY-MM-DD

# %%
data_alldb['date']=pd.to_datetime(data_alldb['date'], format='%Y-%m-%d') # 
data_alldb
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         user                                RowKey       date  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25
# 7      04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27
# ...      ...                                   ...        ...
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
# 40017  12345                        zgvicawbkg.png        NaT
#
#                   phone   site      time                 urine   ov  \
# 1            iPhone10,4  05310  10:50:32                   NaN  NaN
# 5            iPhone13,2  05248  10:14:46                   NaN  NaN
# 7            iPhone10,4  05310  11:14:21                   NaN  NaN
# 11           iPhone13,2  05248  10:14:32                   NaN  NaN
# 12           iPhone13,3  22222  17:39:35                   NaN  NaN
# ...                 ...    ...       ...                   ...  ...
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน    0
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง    1
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)    1
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)    1
# 40017  Samsung SM-G998B  xxxxx       NaN       ปกติ (เหลืองใส)    2
#
#       PartitionKey                  title                    age
# 1              NaN  data is not completed  data is not completed
# 5              NaN  data is not completed  data is not completed
# 7              NaN  data is not completed  data is not completed
# 11             NaN  data is not completed  data is not completed
# 12             NaN  data is not completed  data is not completed
# ...            ...                    ...                    ...
# 39813        99999                    NaN                    NaN
# 39814        99999                    NaN                    NaN
# 39815        99999                    NaN                    NaN
# 39816        99999                    NaN                    NaN
# 40017        xxxxx                    NaN                    NaN
#
# [38508 rows x 11 columns]

# %%
data_alldb.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_alldb
# Out:
# user            False
# RowKey          False
# date             True
# phone           False
# site             True
# time             True
# urine            True
# ov               True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %%
data_alldb['date'] = data_alldb[['date']].fillna(method="ffill")      
data_alldb.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      user                                RowKey       date       phone   site  \
# 1   04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24  iPhone10,4  05310
# 5   08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25  iPhone13,2  05248
# 7   04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24  iPhone10,4  05310
# 11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25  iPhone13,2  05248
# 12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27  iPhone13,3  22222
#
#         time urine   ov PartitionKey                  title  \
# 1   10:50:32   NaN  NaN          NaN  data is not completed
# 5   10:14:46   NaN  NaN          NaN  data is not completed
# 7   11:14:21   NaN  NaN          NaN  data is not completed
# 11  10:14:32   NaN  NaN          NaN  data is not completed
# 12  17:39:35   NaN  NaN          NaN  data is not completed
#
#                       age
# 1   data is not completed
# 5   data is not completed
# 7   data is not completed
# 11  data is not completed
# 12  data is not completed

# %%
data_alldb.shape
# Out:
# (38508, 11)

# %%
data_alldb.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_alldb
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site             True
# time             True
# urine            True
# ov               True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %% [markdown]
# ## phone เป็น String

# %%
data_alldb['phone'] = data_alldb['phone'].astype('str')
data_alldb.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      user                                RowKey       date       phone   site  \
# 1   04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24  iPhone10,4  05310
# 5   08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25  iPhone13,2  05248
# 7   04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24  iPhone10,4  05310
# 11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25  iPhone13,2  05248
# 12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27  iPhone13,3  22222
#
#         time urine   ov PartitionKey                  title  \
# 1   10:50:32   NaN  NaN          NaN  data is not completed
# 5   10:14:46   NaN  NaN          NaN  data is not completed
# 7   11:14:21   NaN  NaN          NaN  data is not completed
# 11  10:14:32   NaN  NaN          NaN  data is not completed
# 12  17:39:35   NaN  NaN          NaN  data is not completed
#
#                       age
# 1   data is not completed
# 5   data is not completed
# 7   data is not completed
# 11  data is not completed
# 12  data is not completed

# %%
data_alldb.shape
# Out:
# (38508, 11)

# %% [markdown]
# ## site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data_alldb = data_alldb[(data_all['site'].astype(str).str.isdigit())& (data_all['site'].str.len() == 5)]
data_alldb
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         user                                RowKey       date  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25
# 7      04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27
# ...      ...                                   ...        ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
#
#                   phone   site      time                 urine   ov  \
# 1            iPhone10,4  05310  10:50:32                   NaN  NaN
# 5            iPhone13,2  05248  10:14:46                   NaN  NaN
# 7            iPhone10,4  05310  11:14:21                   NaN  NaN
# 11           iPhone13,2  05248  10:14:32                   NaN  NaN
# 12           iPhone13,3  22222  17:39:35                   NaN  NaN
# ...                 ...    ...       ...                   ...  ...
# 39812        iPhone14,2  99999  11:36:34                  ขุ่น    1
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน    0
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง    1
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)    1
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)    1
#
#       PartitionKey                  title                    age
# 1              NaN  data is not completed  data is not completed
# 5              NaN  data is not completed  data is not completed
# 7              NaN  data is not completed  data is not completed
# 11             NaN  data is not completed  data is not completed
# 12             NaN  data is not completed  data is not completed
# ...            ...                    ...                    ...
# 39812        99999                    NaN                    NaN
# 39813        99999                    NaN                    NaN
# 39814        99999                    NaN                    NaN
# 39815        99999                    NaN                    NaN
# 39816        99999                    NaN                    NaN
#
# [38493 rows x 11 columns]

# %%
set(data_alldb['site'])
# Out:
# {'00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '06521',
#  '08485',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11111',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11740',
#  '11748',
#  '11749',
#  '11800',
#  '11887',
#  '13377',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '13987',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '20510',
#  '22222',
#  '24622',
#  '24650',
#  '27988',
#  '27990',
#  '27998',
#  '28017',
#  '28691',
#  '28789',
#  '44902',
#  '45972',
#  '49741',
#  '50210',
#  '75757',
#  '97255',
#  '99795',
#  '99999'}

# %% [markdown]
# ## time เป็น hh-mm-ss

# %%
data_alldb['time']=data_alldb['time'].replace(':','-',regex=True)
data_alldb
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         user                                RowKey       date  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25
# 7      04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27
# ...      ...                                   ...        ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
#
#                   phone   site      time                 urine   ov  \
# 1            iPhone10,4  05310  10-50-32                   NaN  NaN
# 5            iPhone13,2  05248  10-14-46                   NaN  NaN
# 7            iPhone10,4  05310  11-14-21                   NaN  NaN
# 11           iPhone13,2  05248  10-14-32                   NaN  NaN
# 12           iPhone13,3  22222  17-39-35                   NaN  NaN
# ...                 ...    ...       ...                   ...  ...
# 39812        iPhone14,2  99999  11-36-34                  ขุ่น    1
# 39813  Samsung SM-G998B  99999  18-10-29               มีตะกอน    0
# 39814  Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง    1
# 39815  Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)    1
# 39816  Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)    1
#
#       PartitionKey                  title                    age
# 1              NaN  data is not completed  data is not completed
# 5              NaN  data is not completed  data is not completed
# 7              NaN  data is not completed  data is not completed
# 11             NaN  data is not completed  data is not completed
# 12             NaN  data is not completed  data is not completed
# ...            ...                    ...                    ...
# 39812        99999                    NaN                    NaN
# 39813        99999                    NaN                    NaN
# 39814        99999                    NaN                    NaN
# 39815        99999                    NaN                    NaN
# 39816        99999                    NaN                    NaN
#
# [38493 rows x 11 columns]

# %%
set(data_alldb['time'])
# Out:
# {nan,
#  '15-48-28',
#  '09-22-04',
#  '10-18-10',
#  '15-01-29',
#  '11-03-21',
#  '07-30-19',
#  '15-48-42',
#  '12-23-30',
#  '14-42-18',
#  '11-20-58',
#  '09-00-12',
#  '11-32-05',
#  '17-20-05',
#  '11-57-48',
#  '13-57-49',
#  '14-07-46',
#  '09-53-32',
#  '12-41-45',
#  '17-46-51',
#  '14-40-03',
#  '12-16-50',
#  '17-52-26',
#  '11-59-49',
#  '14-52-14',
#  '20-09-16',
#  '12-46-05',
#  '11-39-16',
#  '14-03-03',
#  '15-20-14',
#  '15-10-16',
#  '15-40-27',
#  '16-24-58',
#  '16-06-49',
#  '14-38-11',
#  '15-15-26',
#  '10-16-13',
#  '09-43-11',
#  '10-29-00',
#  '15-28-16',
#  '15-44-59',
#  '14-05-57',
#  '14-09-15',
#  '14-15-36',
#  '16-45-29',
#  '14-23-54',
#  '10-05-10',
#  '15-01-44',
#  '15-13-38',
#  '11-52-07',
#  '16-08-57',
#  '11-58-14',
#  '10-55-47',
#  '11-34-50',
#  '09-07-10',
#  '15-33-38',
#  '11-06-21',
#  '15-03-09',
#  '15-48-26',
#  '10-43-19',
#  '16-11-08',
#  '15-42-29',
#  '16-10-04',
#  '14-50-50',
#  '10-58-06',
#  '11-46-18',
#  '17-07-37',
#  '15-07-28',
#  '10-08-41',
#  '11-21-20',
#  '14-55-51',
#  '11-01-13',
#  '15-27-03',
#  '09-36-23',
#  '17-26-49',
#  '14-39-40',
#  '11-19-23',
#  '14-27-45',
#  '14-07-31',
#  '10-46-38',
#  '11-01-06',
#  '10-19-03',
#  '14-45-08',
#  '14-49-21',
#  '19-58-53',
#  '17-11-37',
#  '14-17-59',
#  '15-41-17',
#  '10-24-18',
#  '14-03-10',
#  '15-13-24',
#  '17-31-37',
#  '20-47-40',
#  '11-41-44',
#  '11-19-48',
#  '13-24-53',
#  '16-07-13',
#  '11-05-59',
#  '10-35-19',
#  '09-45-39',
#  '14-29-28',
#  '13-18-21',
#  '16-38-30',
#  '10-57-02',
#  '14-29-11',
#  '15-35-04',
#  '13-37-31',
#  '16-53-56',
#  '16-36-56',
#  '10-07-32',
#  '08-35-20',
#  '15-03-00',
#  '12-39-23',
#  '18-21-33',
#  '10-24-31',
#  '09-22-20',
#  '16-09-55',
#  '15-21-11',
#  '13-59-10',
#  '08-47-03',
#  '17-07-44',
#  '15-19-51',
#  '11-10-56',
#  '10-19-44',
#  '16-54-05',
#  '12-23-03',
#  '10-59-54',
#  '11-56-18',
#  '11-46-34',
#  '09-20-38',
#  '11-22-59',
#  '10-40-10',
#  '13-43-25',
#  '10-21-25',
#  '16-25-47',
#  '13-15-19',
#  '15-14-03',
#  '11-45-07',
#  '10-11-23',
#  '10-04-01',
#  '16-19-43',
#  '12-06-28',
#  '17-09-09',
#  '10-59-58',
#  '10-05-16',
#  '15-42-56',
#  '11-35-00',
#  '11-11-20',
#  '13-40-17',
#  '14-49-35',
#  '17-07-25',
#  '12-32-45',
#  '10-07-13',
#  '14-22-41',
#  '09-34-58',
#  '10-06-14',
#  '13-44-35',
#  '14-10-02',
#  '16-59-29',
#  '09-28-57',
#  '13-25-24',
#  '10-28-10',
#  '13-03-08',
#  '13-52-45',
#  '10-30-00',
#  '15-57-59',
#  '13-02-32',
#  '23-22-12',
#  '14-52-57',
#  '21-58-41',
#  '11-08-46',
#  '11-05-07',
#  '09-35-56',
#  '10-12-39',
#  '10-48-19',
#  '11-36-47',
#  '16-21-46',
#  '11-02-40',
#  '11-27-44',
#  '10-20-24',
#  '14-25-04',
#  '19-52-28',
#  '16-42-01',
#  '13-02-04',
#  '22-02-13',
#  '15-20-52',
#  '12-13-19',
#  '10-11-39',
#  '13-57-08',
#  '10-22-22',
#  '16-31-01',
#  '14-26-11',
#  '16-12-57',
#  '12-40-34',
#  '11-09-58',
#  '17-29-28',
#  '11-50-00',
#  '19-21-32',
#  '10-43-53',
#  '10-00-08',
#  '09-08-43',
#  '15-33-04',
#  '09-17-12',
#  '10-27-56',
#  '12-14-52',
#  '16-35-23',
#  '10-51-53',
#  '10-02-56',
#  '16-05-04',
#  '17-49-41',
#  '12-31-43',
#  '11-45-06',
#  '11-35-02',
#  '12-01-00',
#  '09-46-17',
#  '10-15-41',
#  '16-00-06',
#  '16-22-12',
#  '11-15-12',
#  '12-53-02',
#  '14-34-09',
#  '16-09-08',
#  '11-49-19',
#  '13-41-51',
#  '12-27-40',
#  '11-57-04',
#  '11-26-46',
#  '12-56-31',
#  '16-13-43',
#  '20-46-03',
#  '12-23-20',
#  '10-27-26',
#  '11-04-32',
#  '11-49-05',
#  '14-00-53',
#  '11-30-03',
#  '13-08-39',
#  '15-37-07',
#  '14-38-21',
#  '15-45-33',
#  ...}

# %% [markdown]
# ## urine มีค่า String

# %%
data_alldb['urine'] = data_alldb['urine'].astype('str')
data_alldb.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      user                                RowKey       date       phone   site  \
# 1   04857  136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24  iPhone10,4  05310
# 5   08777  472EED3E-E2A7-4551-9249-D87747C68AFD 2022-02-25  iPhone13,2  05248
# 7   04857  73E96EE6-7660-4204-9914-92112603C514 2022-02-24  iPhone10,4  05310
# 11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9 2022-02-25  iPhone13,2  05248
# 12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2 2022-02-27  iPhone13,3  22222
#
#         time urine   ov PartitionKey                  title  \
# 1   10-50-32   nan  NaN          NaN  data is not completed
# 5   10-14-46   nan  NaN          NaN  data is not completed
# 7   11-14-21   nan  NaN          NaN  data is not completed
# 11  10-14-32   nan  NaN          NaN  data is not completed
# 12  17-39-35   nan  NaN          NaN  data is not completed
#
#                       age
# 1   data is not completed
# 5   data is not completed
# 7   data is not completed
# 11  data is not completed
# 12  data is not completed

# %%
set(data_alldb['urine'])
# Out:
# {'nan',
#  'ขุ่น',
#  'ขุ่น, มีตะกอน',
#  'ขุ่น, มีตะกอน, มีเม็ดเลือดแดง',
#  'ขุ่น, มีตะกอน, สีเหลืองส้ม (ผิดปกติ)',
#  'ขุ่น, มีเม็ดเลือดแดง',
#  'ขุ่น, สีน้ำนม',
#  'ขุ่น, สีเหลืองส้ม (ผิดปกติ)',
#  'ขุ่น, ใส่เป็นน้ำเปล่า',
#  'ปกติ (เหลืองใส)',
#  'ปกติ (เหลืองใส), ขุ่น',
#  'ปกติ (เหลืองใส), ขุ่น, มีตะกอน',
#  'ปกติ (เหลืองใส), มีตะกอน',
#  'ปกติ (เหลืองใส), มีตะกอน, สีเหลืองส้ม (ผิดปกติ)',
#  'ปกติ (เหลืองใส), มีเม็ดเลือดแดง',
#  'ปกติ (เหลืองใส), สีน้ำนม',
#  'ปกติ (เหลืองใส), สีเหลืองส้ม (ผิดปกติ)',
#  'ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า',
#  'ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า, สีน้ำนม',
#  'มีตะกอน',
#  'มีตะกอน, มีเม็ดเลือดแดง',
#  'มีตะกอน, มีเม็ดเลือดแดง, สีเหลืองส้ม (ผิดปกติ)',
#  'มีตะกอน, มีเลือดปน',
#  'มีตะกอน, สีเหลืองส้ม (ผิดปกติ)',
#  'มีตะกอน, ใส่เป็นน้ำเปล่า',
#  'มีเม็ดเลือดแดง',
#  'มีเลือดปน',
#  'มีเลือดปน, สีเหลืองส้ม (ผิดปกติ)',
#  'สีน้ำนม',
#  'สีฟ้า หรือน้ำเงิน',
#  'สีเหลืองส้ม (ผิดปกติ)',
#  'ใสเป็นน้ำเปล่า',
#  'ใส่เป็นน้ำเปล่า',
#  'ใส่เป็นน้ำเปล่า, สีฟ้า หรือน้ำเงิน'}

# %% [markdown]
# ## ov เป็นตัวเลข มีค่าตั้งแต่ 0-4
# (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)

# %%
import numpy as np

# %%
set(data_alldb['ov'])
# Out:
# {'0', '1', '2', '3', '4', nan, 'ติดเชื้อ +2 '}

# %%
data_alldb['ov'] = pd.to_numeric(data_alldb['ov'], errors='coerce') # เปลี่ยนให้เป็นตัวเลขเท่านั้น
data_alldb = data_alldb.replace(np.nan, 0, regex=True)    # เปลี่ยนจากค่าว่างให้เป็น 0
data_alldb['ov'] = data_alldb['ov'].astype(int)    # เปลี่ยน type ของ ov ให้เป็น
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
set(data_alldb['ov'])
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# ## PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data_alldb = data_alldb[(data_all['PartitionKey'].astype(str).str.isdigit())& (data_all['PartitionKey'].str.len() == 5)]
data_alldb
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         user                                RowKey       date  \
# 190    06223                        kfpwuaqldj.png 2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 191           iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 192           iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 193           iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 194            iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey   title age
# 190          00000       0   0
# 191          00001  นางสาว  47
# 192          00001     นาง  41
# 193          00001     นาง  55
# 194          00001     นาย  66
# ...            ...     ...  ..
# 39812        99999       0   0
# 39813        99999       0   0
# 39814        99999       0   0
# 39815        99999       0   0
# 39816        99999       0   0
#
# [38382 rows x 11 columns]

# %%
set(data_alldb['PartitionKey'])
# Out:
# {'00323',
#  '01216',
#  '09004',
#  '01943',
#  '11005',
#  '00033',
#  '01765',
#  '02631',
#  '03199',
#  '01954',
#  '05209',
#  '02896',
#  '01239',
#  '02271',
#  '00721',
#  '01196',
#  '02420',
#  '06060',
#  '00975',
#  '04084',
#  '00822',
#  '04127',
#  '01878',
#  '00758',
#  '05957',
#  '00724',
#  '04654',
#  '02356',
#  '03101',
#  '08906',
#  '05155',
#  '01431',
#  '01288',
#  '02672',
#  '05994',
#  '02632',
#  '00014',
#  '01055',
#  '01492',
#  '02075',
#  '02215',
#  '05721',
#  '00380',
#  '01519',
#  '02383',
#  '03366',
#  '00500',
#  '10968',
#  '02103',
#  '05960',
#  '01628',
#  '03553',
#  '00354',
#  '00969',
#  '00027',
#  '00550',
#  '01109',
#  '00038',
#  '03425',
#  '04664',
#  '03715',
#  '01498',
#  '00804',
#  '01171',
#  '02163',
#  '01856',
#  '02377',
#  '09026',
#  '01623',
#  '03538',
#  '04036',
#  '08909',
#  '03977',
#  '00508',
#  '05290',
#  '02487',
#  '03008',
#  '01577',
#  '01566',
#  '02466',
#  '01092',
#  '04115',
#  '00674',
#  '00840',
#  '02251',
#  '05110',
#  '01828',
#  '08938',
#  '01056',
#  '02811',
#  '02856',
#  '04738',
#  '02877',
#  '03313',
#  '08966',
#  '01615',
#  '00011',
#  '05828',
#  '00328',
#  '00771',
#  '02116',
#  '01537',
#  '00876',
#  '05959',
#  '01572',
#  '08989',
#  '01131',
#  '02350',
#  '09008',
#  '01977',
#  '00052',
#  '00335',
#  '02819',
#  '00251',
#  '00621',
#  '02857',
#  '02063',
#  '01711',
#  '01927',
#  '02405',
#  '05153',
#  '10996',
#  '01028',
#  '09010',
#  '00032',
#  '04090',
#  '02406',
#  '02355',
#  '03074',
#  '01781',
#  '05235',
#  '00352',
#  ...}

# %%
data_alldb
# Out:
#         user                                RowKey       date  \
# 190    06223                        kfpwuaqldj.png 2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 191           iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 192           iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 193           iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 194            iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey   title age
# 190          00000       0   0
# 191          00001  นางสาว  47
# 192          00001     นาง  41
# 193          00001     นาง  55
# 194          00001     นาย  66
# ...            ...     ...  ..
# 39812        99999       0   0
# 39813        99999       0   0
# 39814        99999       0   0
# 39815        99999       0   0
# 39816        99999       0   0
#
# [38382 rows x 11 columns]

# %% [markdown]
# ## แก้ค่า title

# %%
set(data_alldb['title'])
# Out:
# {'  นาง',
#  ' นาง',
#  ' นางสาว',
#  ' นาย',
#  0,
#  'Mrs',
#  'ชาย',
#  'ด.ช.',
#  'ด.ญ.',
#  'ด.ต.',
#  'น',
#  'น.ส',
#  'น.ส ',
#  'น.ส.',
#  'นส',
#  'นส.',
#  'นส. ',
#  'นาง',
#  'นาง ',
#  'นาง.',
#  'นางl',
#  'นางสาว',
#  'นางสาว ',
#  'นางสาว                   ',
#  'นาน',
#  'นาบ',
#  'นาย',
#  'นาย ',
#  'นาย  ',
#  'นาว',
#  'นาวสาว',
#  'นา่ง',
#  'น่าย',
#  'พจอ.',
#  'พระ',
#  'พระครุ',
#  'พระปลัด',
#  'พลฯ',
#  'ร.ต.',
#  'ร.ต.ต.',
#  'ร.ต.ท.',
#  'ร.ต.อ.',
#  'รต.',
#  'ว่าที่ ร.ต.',
#  'ว่าที่ ร.ท.',
#  'ว่าที่ร้อยตรี',
#  'ส.อ.',
#  'ืนาง',
#  'เด็กชาย',
#  'เด็กหญิง'}

# %%
#เปลี่ยนคอลัมน์ title เป็นเพศ

data_alldb['title'].replace({'  นาง':'หญิง',
                    ' นาง':'หญิง',
                    ' นางสาว':'หญิง',
                    ' นาย':'ชาย',
                    'Mrs':'หญิง',
                    'ชาย':'ชาย',
                    'ด.ช.':'ชาย',
                    'ด.ญ.':'หญิง',
                    'ด.ต.':'ไม่ระบุ',
                    'น':'ไม่ระบุ',
                    'น.ส':'หญิง',
                    'น.ส ':'หญิง',
                    'น.ส.':'หญิง',
                    'นส':'หญิง',
                    'นส.':'หญิง',
                    'นส. ':'หญิง',
                    'นาง':'หญิง',
                    'นาง ':'หญิง',
                    'นาง.':'หญิง',
                    'นางl':'หญิง',
                    'นางสาว':'หญิง',
                    'นางสาว ':'หญิง',
                    'นางสาว  ':'หญิง',
                    'นาน':'ชาย',
                    'นาบ':'ชาย',
                    'นาย':'ชาย',
                    'นาย ':'ชาย',
                    'นาย  ':'ชาย',
                    'นาว':'หญิง',
                    'นาวสาว':'หญิง',
                    'นา่ง':'หญิง',
                    'น่าย':'ชาย',
                    'พจอ.':'ไม่ระบุ',
                    'พระ':'ชาย',
                    'พระครุ':'ไม่ระบุ',
                    'พระปลัด':'ไม่ระบุ',
                    'พลฯ':'ไม่ระบุ',
                    'ร.ต.':'ไม่ระบุ',
                    'ร.ต.ต.':'ไม่ระบุ',
                    'ร.ต.ท.':'ไม่ระบุ',
                    'ร.ต.อ.':'ไม่ระบุ',
                    'รต.':'ไม่ระบุ',
                    'ว่าที่ ร.ต.':'ไม่ระบุ',
                    'ว่าที่ ร.ท.':'ไม่ระบุ',
                    'ว่าที่ร้อยตรี':'ไม่ระบุ',
                    0:'ไม่ระบุ',
                    'data is not completed':'ไม่ระบุ',
                    'okp':'ไม่ระบุ',
                    'ส.อ.':'ไม่ระบุ',
                    'ืนาง':'หญิง',
                    'เด็กชาย':'ชาย',
                    'นางสาว                   ':'หญิง',
                    'เด็กหญิง':'หญิง'},inplace=True)

# %%
set(data_alldb['title'])
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %%
data_alldb = data_alldb.rename(columns={'title':'sex'})  # เปลี่ยนชื่อคอลัมน์จาก title เป็น sex
data_alldb
# Out:
#         user                                RowKey       date  \
# 190    06223                        kfpwuaqldj.png 2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 39813  99999                        lnlohgqckf.png 2022-03-10
# 39814  99999                        vkdocpmjiv.png 2022-03-10
# 39815  99999                        vrvyfnvayq.png 2022-03-10
# 39816  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 191           iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 192           iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 193           iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 194            iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey      sex age
# 190          00000  ไม่ระบุ   0
# 191          00001     หญิง  47
# 192          00001     หญิง  41
# 193          00001     หญิง  55
# 194          00001      ชาย  66
# ...            ...      ...  ..
# 39812        99999  ไม่ระบุ   0
# 39813        99999  ไม่ระบุ   0
# 39814        99999  ไม่ระบุ   0
# 39815        99999  ไม่ระบุ   0
# 39816        99999  ไม่ระบุ   0
#
# [38382 rows x 11 columns]

# %% [markdown]
# # นำเข้าข้อมูล hospital_list.xlsx

# %%
hospital_file = os.path.join(path,'hospital_list.xlsx')
data_hospital = pd.read_excel(hospital_file)
data_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ## ดูประเภทของข้อมูล

# %%
data_hospital.dtypes    #ดู type ของข้อมูล
# Out:
# hcode             object
# name              object
# zone_code          int64
# zone_name         object
# provincecode     float64
# province          object
# amphurcode       float64
# amphur            object
# tamboncode       float64
# tambon            object
# code4            float64
# name5             object
# code9            float64
# name10            object
# short_thai        object
# short_english     object
# dtype: object

# %% [markdown]
# ## เลือกเฉพาะคอลัมน์ที่ต้องการ

# %%
data_hospital= data_hospital[['hcode','name','zone_name','province','amphur','tambon','name5']]   # กำหนดให้ตารางชื่อ data_alldb_df โดยทำการเลือกเก็บข้อมูลในตาราง data_alldb จำนวนทั้งหมด 9  คอลัมน์ 
data_hospital
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# 1          สาขาพื้นที่(สระบุรี)          นนทบุรี      เมืองนนทบุรี   บางกระสอ
# 2          สาขาพื้นที่(สระบุรี)         ปทุมธานี     เมืองปทุมธานี    บางปรอก
# 3          สาขาพื้นที่(สระบุรี)  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย
# 4          สาขาพื้นที่(สระบุรี)          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ
# ...                         ...              ...               ...        ...
# 17098     สาขาพื้นที่(พิษณุโลก)        อุตรดิตถ์    เมืองอุตรดิตถ์     ท่าอิฐ
# 17099      สาขาพื้นที่(ราชบุรี)  ประจวบคีรีขันธ์           กุยบุรี    กุยบุรี
# 17100      สาขาพื้นที่(ราชบุรี)          ราชบุรี           วัดเพลง    วัดเพลง
# 17101  สาขาพื้นที่(อุบลราชธานี)         ศรีสะเกษ     เมืองศรีสะเกษ     โพนข่า
# 17102      สาขาพื้นที่(ราชบุรี)          ราชบุรี             บางแพ    วังเย็น
#
#                           name5
# 0      สำนักงานสาธารณสุขจังหวัด
# 1      สำนักงานสาธารณสุขจังหวัด
# 2      สำนักงานสาธารณสุขจังหวัด
# 3      สำนักงานสาธารณสุขจังหวัด
# 4      สำนักงานสาธารณสุขจังหวัด
# ...                         ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.
#
# [17103 rows x 7 columns]

# %% [markdown]
# ## เปลี่ยนชื่อคอลัมน์

# %%
data_hospital = data_hospital.rename(columns={'name5':'type'})  #     เปลี่ยนชื่อ คอลัมน์ name5 ให้ชื่อคอลัมน์เป็น type
data_hospital
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# 1          สาขาพื้นที่(สระบุรี)          นนทบุรี      เมืองนนทบุรี   บางกระสอ
# 2          สาขาพื้นที่(สระบุรี)         ปทุมธานี     เมืองปทุมธานี    บางปรอก
# 3          สาขาพื้นที่(สระบุรี)  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย
# 4          สาขาพื้นที่(สระบุรี)          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ
# ...                         ...              ...               ...        ...
# 17098     สาขาพื้นที่(พิษณุโลก)        อุตรดิตถ์    เมืองอุตรดิตถ์     ท่าอิฐ
# 17099      สาขาพื้นที่(ราชบุรี)  ประจวบคีรีขันธ์           กุยบุรี    กุยบุรี
# 17100      สาขาพื้นที่(ราชบุรี)          ราชบุรี           วัดเพลง    วัดเพลง
# 17101  สาขาพื้นที่(อุบลราชธานี)         ศรีสะเกษ     เมืองศรีสะเกษ     โพนข่า
# 17102      สาขาพื้นที่(ราชบุรี)          ราชบุรี             บางแพ    วังเย็น
#
#                            type
# 0      สำนักงานสาธารณสุขจังหวัด
# 1      สำนักงานสาธารณสุขจังหวัด
# 2      สำนักงานสาธารณสุขจังหวัด
# 3      สำนักงานสาธารณสุขจังหวัด
# 4      สำนักงานสาธารณสุขจังหวัด
# ...                         ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.
#
# [17103 rows x 7 columns]

# %% [markdown]
# ## ตรวจสอบเเละแทนค่า Missing ด้วยค่าที่เหมาะสม

# %%
data_hospital.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง
# Out:
# hcode        False
# name          True
# zone_name     True
# province     False
# amphur        True
# tambon        True
# type          True
# dtype: bool

# %%
data_hospital= data_hospital.fillna(value={'name':'ไม่ระบุ','zone_name':'ไม่ระบุ','amphur':'ไม่ระบุ','tambon':'ไม่ระบุ','type':'ไม่ระบุ'}) #แทน missing ด้วยค่าที่เหมาะสม 
data_hospital # แสดงตาราง data_hospital_list_df
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# 1          สาขาพื้นที่(สระบุรี)          นนทบุรี      เมืองนนทบุรี   บางกระสอ
# 2          สาขาพื้นที่(สระบุรี)         ปทุมธานี     เมืองปทุมธานี    บางปรอก
# 3          สาขาพื้นที่(สระบุรี)  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย
# 4          สาขาพื้นที่(สระบุรี)          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ
# ...                         ...              ...               ...        ...
# 17098     สาขาพื้นที่(พิษณุโลก)        อุตรดิตถ์    เมืองอุตรดิตถ์     ท่าอิฐ
# 17099      สาขาพื้นที่(ราชบุรี)  ประจวบคีรีขันธ์           กุยบุรี    กุยบุรี
# 17100      สาขาพื้นที่(ราชบุรี)          ราชบุรี           วัดเพลง    วัดเพลง
# 17101  สาขาพื้นที่(อุบลราชธานี)         ศรีสะเกษ     เมืองศรีสะเกษ     โพนข่า
# 17102      สาขาพื้นที่(ราชบุรี)          ราชบุรี             บางแพ    วังเย็น
#
#                            type
# 0      สำนักงานสาธารณสุขจังหวัด
# 1      สำนักงานสาธารณสุขจังหวัด
# 2      สำนักงานสาธารณสุขจังหวัด
# 3      สำนักงานสาธารณสุขจังหวัด
# 4      สำนักงานสาธารณสุขจังหวัด
# ...                         ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.
#
# [17103 rows x 7 columns]

# %%
data_hospital.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง
# Out:
# hcode        False
# name         False
# zone_name    False
# province     False
# amphur       False
# tambon       False
# type         False
# dtype: bool

# %% [markdown]
# # รวมตาราง

# %%
data_final = data_alldb.merge(data_hospital,how='left', left_on='site',right_on='hcode')
data_final
# Out:
#         user                                RowKey       date  \
# 0      06223                        kfpwuaqldj.png 2022-03-23
# 1      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 2      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 3      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 4      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 38377  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 38378  99999                        lnlohgqckf.png 2022-03-10
# 38379  99999                        vkdocpmjiv.png 2022-03-10
# 38380  99999                        vrvyfnvayq.png 2022-03-10
# 38381  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 0      Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 1             iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 2             iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 3             iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 4              iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 38377         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 38378   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 38379   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 38380   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 38381   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey      sex age  hcode  \
# 0            00000  ไม่ระบุ   0  13777
# 1            00001     หญิง  47  06307
# 2            00001     หญิง  41  05328
# 3            00001     หญิง  55  06302
# 4            00001      ชาย  66  05059
# ...            ...      ...  ..    ...
# 38377        99999  ไม่ระบุ   0    NaN
# 38378        99999  ไม่ระบุ   0    NaN
# 38379        99999  ไม่ระบุ   0    NaN
# 38380        99999  ไม่ระบุ   0    NaN
# 38381        99999  ไม่ระบุ   0    NaN
#
#                                                     name  \
# 0                โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 2            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 3                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 4                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# ...                                                  ...
# 38377                                                NaN
# 38378                                                NaN
# 38379                                                NaN
# 38380                                                NaN
# 38381                                                NaN
#
#                    zone_name   province        amphur    tambon  \
# 0       สาขาพื้นที่(ขอนแก่น)    ขอนแก่น  เมืองขอนแก่น   ในเมือง
# 1      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์         พิชัย  บ้านดารา
# 2       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์       ฆ้องชัย  โคกสะอาด
# 3      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์        ฟากท่า   สองห้อง
# 4       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม         นาดูน     หัวดง
# ...                      ...        ...           ...       ...
# 38377                    NaN        NaN           NaN       NaN
# 38378                    NaN        NaN           NaN       NaN
# 38379                    NaN        NaN           NaN       NaN
# 38380                    NaN        NaN           NaN       NaN
# 38381                    NaN        NaN           NaN       NaN
#
#                               type
# 0                โรงพยาบาล นอก สธ.
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล
# ...                            ...
# 38377                          NaN
# 38378                          NaN
# 38379                          NaN
# 38380                          NaN
# 38381                          NaN
#
# [38382 rows x 18 columns]

# %%
data_final.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# sex             False
# age             False
# hcode            True
# name             True
# zone_name        True
# province         True
# amphur           True
# tambon           True
# type             True
# dtype: bool

# %%
data_final= data_final.fillna(value={'hcode':'ไม่ระบุ','name':'ไม่ระบุ','zone_name':'ไม่ระบุ','province':'ไม่ระบุ','amphur':'ไม่ระบุ','tambon':'ไม่ระบุ','type':'ไม่ระบุ'}) #แทน missing ด้วยค่าที่เหมาะสม 
data_final # แสดงตาราง data_hospital_list_df
# Out:
#         user                                RowKey       date  \
# 0      06223                        kfpwuaqldj.png 2022-03-23
# 1      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 2      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 3      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 4      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 38377  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 38378  99999                        lnlohgqckf.png 2022-03-10
# 38379  99999                        vkdocpmjiv.png 2022-03-10
# 38380  99999                        vrvyfnvayq.png 2022-03-10
# 38381  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 0      Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 1             iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 2             iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 3             iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 4              iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 38377         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 38378   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 38379   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 38380   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 38381   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey      sex age    hcode  \
# 0            00000  ไม่ระบุ   0    13777
# 1            00001     หญิง  47    06307
# 2            00001     หญิง  41    05328
# 3            00001     หญิง  55    06302
# 4            00001      ชาย  66    05059
# ...            ...      ...  ..      ...
# 38377        99999  ไม่ระบุ   0  ไม่ระบุ
# 38378        99999  ไม่ระบุ   0  ไม่ระบุ
# 38379        99999  ไม่ระบุ   0  ไม่ระบุ
# 38380        99999  ไม่ระบุ   0  ไม่ระบุ
# 38381        99999  ไม่ระบุ   0  ไม่ระบุ
#
#                                                     name  \
# 0                โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 2            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 3                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 4                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# ...                                                  ...
# 38377                                            ไม่ระบุ
# 38378                                            ไม่ระบุ
# 38379                                            ไม่ระบุ
# 38380                                            ไม่ระบุ
# 38381                                            ไม่ระบุ
#
#                    zone_name   province        amphur    tambon  \
# 0       สาขาพื้นที่(ขอนแก่น)    ขอนแก่น  เมืองขอนแก่น   ในเมือง
# 1      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์         พิชัย  บ้านดารา
# 2       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์       ฆ้องชัย  โคกสะอาด
# 3      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์        ฟากท่า   สองห้อง
# 4       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม         นาดูน     หัวดง
# ...                      ...        ...           ...       ...
# 38377                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38378                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38379                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38380                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38381                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
#
#                               type
# 0                โรงพยาบาล นอก สธ.
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล
# ...                            ...
# 38377                      ไม่ระบุ
# 38378                      ไม่ระบุ
# 38379                      ไม่ระบุ
# 38380                      ไม่ระบุ
# 38381                      ไม่ระบุ
#
# [38382 rows x 18 columns]

# %%
data_final.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# sex             False
# age             False
# hcode           False
# name            False
# zone_name       False
# province        False
# amphur          False
# tambon          False
# type            False
# dtype: bool

# %%
data_final
# Out:
#         user                                RowKey       date  \
# 0      06223                        kfpwuaqldj.png 2022-03-23
# 1      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 2      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 3      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 4      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 38377  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11
# 38378  99999                        lnlohgqckf.png 2022-03-10
# 38379  99999                        vkdocpmjiv.png 2022-03-10
# 38380  99999                        vrvyfnvayq.png 2022-03-10
# 38381  99999                        zuhbtvyrce.png 2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 0      Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 1             iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)   4
# 2             iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)   4
# 3             iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)   3
# 4              iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)   3
# ...                  ...    ...       ...                   ...  ..
# 38377         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 38378   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 38379   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 38380   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 38381   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#       PartitionKey      sex age    hcode  \
# 0            00000  ไม่ระบุ   0    13777
# 1            00001     หญิง  47    06307
# 2            00001     หญิง  41    05328
# 3            00001     หญิง  55    06302
# 4            00001      ชาย  66    05059
# ...            ...      ...  ..      ...
# 38377        99999  ไม่ระบุ   0  ไม่ระบุ
# 38378        99999  ไม่ระบุ   0  ไม่ระบุ
# 38379        99999  ไม่ระบุ   0  ไม่ระบุ
# 38380        99999  ไม่ระบุ   0  ไม่ระบุ
# 38381        99999  ไม่ระบุ   0  ไม่ระบุ
#
#                                                     name  \
# 0                โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 2            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 3                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 4                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# ...                                                  ...
# 38377                                            ไม่ระบุ
# 38378                                            ไม่ระบุ
# 38379                                            ไม่ระบุ
# 38380                                            ไม่ระบุ
# 38381                                            ไม่ระบุ
#
#                    zone_name   province        amphur    tambon  \
# 0       สาขาพื้นที่(ขอนแก่น)    ขอนแก่น  เมืองขอนแก่น   ในเมือง
# 1      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์         พิชัย  บ้านดารา
# 2       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์       ฆ้องชัย  โคกสะอาด
# 3      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์        ฟากท่า   สองห้อง
# 4       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม         นาดูน     หัวดง
# ...                      ...        ...           ...       ...
# 38377                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38378                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38379                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38380                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
# 38381                ไม่ระบุ    ไม่ระบุ       ไม่ระบุ   ไม่ระบุ
#
#                               type
# 0                โรงพยาบาล นอก สธ.
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล
# ...                            ...
# 38377                      ไม่ระบุ
# 38378                      ไม่ระบุ
# 38379                      ไม่ระบุ
# 38380                      ไม่ระบุ
# 38381                      ไม่ระบุ
#
# [38382 rows x 18 columns]

# %% [markdown]
# # นำข้อมูลไปใช้ทำ Dashboard

# %%
data_final.to_csv(os.path.join(path,'Data.csv'))   # save ตารางให้เป็นไฟล์ csv เข้าไปเก็บไว้ใน drive เพื่อนำข้อมูลไปใช้ทำ Dashboard
